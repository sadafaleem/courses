# %% [markdown]
# Code from 4th class on python after orientation by LUMS course - Data Science and Machine Learning Using Python

# %% [markdown]
# **Data Visualization in Python**

# %% [markdown]
# Libraries in python: Matplotlib, Seaborn, Bokeh

# %% [markdown]
# **Matplotlib**
#
# *   Visualization allows us visual access to huge amounts of data
# *   Matplotlib consists of several plos like line, scatter, bar, histogram etc.

# %%
# import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# **Line Plot**
#
# *   plt.plot(x,y) used to create line plots
# *   A line plot is a graph that represents data points along a number line

# %% [markdown]
# #### Line Plot Example

# %%
#Create line plot of using X & Y values
# importing matplotlib module
import matplotlib.pyplot as plt
# x-axis values
x = [5, 2, 9, 4, 7]
# Y-axis values
y = [10, 5, 8, 4, 2]
# Function to plot
plt.plot(x,y)
# function to show the plot
plt.show()

# %% [markdown]
# **Range Function**

# %%
#create a list using range function
number_list = list(range(1, 10))
#print list
print(number_list)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
year=list(range(1950,2101))
print(year)
# Out:
# [1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050, 2051, 2052, 2053, 2054, 2055, 2056, 2057, 2058, 2059, 2060, 2061, 2062, 2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 2071, 2072, 2073, 2074, 2075, 2076, 2077, 2078, 2079, 2080, 2081, 2082, 2083, 2084, 2085, 2086, 2087, 2088, 2089, 2090, 2091, 2092, 2093, 2094, 2095, 2096, 2097, 2098, 2099, 2100]

# %%
# create range with intervals of 10
year=list(range(1950,2101,10))
print(year)
# Out:
# [1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020, 2030, 2040, 2050, 2060, 2070, 2080, 2090, 2100]

# %% [markdown]
# **Task**
# Create line plot of world projected population. Year should be mapped on
# the horizontal axis, population on the vertical axis.

# %%
# population list 
pop=[2.53,2.57,2.62,2.67,2.71,2.76,2.81,2.86,2.92,2.97,3.03,3.08,3.14,3.2,3.26,3.33,3.4,3.47,3.54,3.62,3.69,3.77,3.84,3.92,4.,4.07,4.15,4.22,4.3,4.37,4.45,4.53,4.61,4.69,4.78,4.86,4.95,5.05,5.14,5.23,5.32,5.41,5.49,5.58,5.66,5.74,5.82,5.9,5.98,6.05,6.13,6.2,6.28,6.36,6.44,6.51,6.59,6.67,6.75,6.83,6.92,7.,7.08,7.16,7.24,7.32,7.4,7.48,7.56,7.64,7.72,7.79,7.87,7.94,8.01,8.08,8.15,8.22,8.29,8.36,8.42,8.49,8.56,8.62,8.68,8.74,8.8,8.86,8.92,8.98,9.04,9.09,9.15,9.2,9.26,9.31,9.36,9.41,9.46,9.5,9.55,9.6,9.64,9.68,9.73,9.77,9.81,9.85,9.88,9.92,9.96,9.99,10.03,10.06,10.09,10.13,10.16,10.19,10.22,10.25,10.28,10.31,10.33,10.36,10.38,10.41,10.43,10.46,10.48,10.5,10.52,10.55,10.57,10.59,10.61,10.63,10.65,10.66,10.68,10.7,10.72,10.73,10.75,10.77,10.78,10.79,10.81,10.82,10.83,10.84,10.85]

# %%
#Use the list you created for year 1950 to 2101
year=list(range(1950,2101))

# print graph plt.plot(x,y)
plt.plot(year, pop)

plt.xlabel("Year")
plt.ylabel("Population")

plt.show()

# %% [markdown]
# **Task**
# Create a line plot using the following data for monthly savings.

# %%
month=["Jan", "Feb", "Mar","Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]


savings=[209.00, 250.00, 209.00, 297.00, 356.00, 388.00, 305.00, 397.00, 362.00, 237.00, 282.00, 238.00]

plt.plot(month, savings)
plt.show()

# %% [markdown]
# **Task**
# Print the last item from both the list (GDP per Capita) gdp_cap, and the list (Life
# Expectancy) life_exp.

# %%
import pandas as pd
import numpy as np
country_Data = pd.read_csv('https://raw.githubusercontent.com/Masadn/PythonCourse/master/dataset/gapminder.csv')

# Converting pandas DataFrame to Numpy array
np_country_Data=np.array(country_Data)

# extracting all rows from 6th column (GDP)
gdp_cap=np_country_Data[:,6]

#Extracting all rows from 5th column (Life expectancy)
life_exp = np_country_Data[:,5]
#gdp_cap, which contains the GDP per capita (i.e. per person) for each country expressed in US Dollars.
#life_exp which contains the life expectancy for each country

# %%
print(country_Data.head())
# Out:
#    Unnamed: 0      country  year  population      cont  life_exp       gdp_cap
# 0          11  Afghanistan  2007    31889923      Asia    43.828    974.580338
# 1          23      Albania  2007     3600523    Europe    76.423   5937.029526
# 2          35      Algeria  2007    33333216    Africa    72.301   6223.367465
# 3          47       Angola  2007    12420476    Africa    42.731   4797.231267
# 4          59    Argentina  2007    40301927  Americas    75.320  12779.379640

# %%
print(type(np_country_Data))
# Out:
# <class 'numpy.ndarray'>

# %%
print(life_exp)
# Out:
# [43.828 76.423 72.301 42.731 75.32 81.235 79.829 75.635 64.062 79.441
#  56.728 65.554 74.852 50.728 72.39 73.005 52.295 49.58 59.723 50.43 80.653
#  44.741 50.651 78.553 72.961 72.889 65.152 46.462 55.322 78.782 48.328
#  75.748 78.273 76.486 78.332 54.791 72.235 74.994 71.338 71.878 51.579
#  58.04 52.947 79.313 80.657 56.735 59.448 79.406 60.022 79.483 70.259
#  56.007 46.388 60.916 70.198 82.208 73.338 81.757 64.698 70.65 70.964
#  59.545 78.885 80.745 80.546 72.567 82.603 72.535 54.11 67.297 78.623
#  77.588 71.993 42.592 45.678 73.952 59.443 48.303 74.241 54.467 64.164
#  72.801 76.195 66.803 74.543 71.164 42.082 62.069 52.906 63.785 79.762
#  80.204 72.899 56.867 46.859 80.196 75.64 65.483 75.537 71.752 71.421
#  71.688 75.563 78.098 78.746 76.442 72.476 46.242 65.528 72.777 63.062
#  74.002 42.568 79.972 74.663 77.926 48.159 49.339 80.941 72.396 58.556
#  39.613 80.884 81.701 74.143 78.4 52.517 70.616 58.42 69.819 73.923 71.777
# ...

# %%
print(gdp_cap[-1])
# Out:
# 469.7092981

# %%
print(life_exp[-1])
# Out:
# 43.487

# %% [markdown]
# **Task:** Build a line chart, with gdp_cap and life_exp.

# %%
plt.plot(life_exp, gdp_cap)

plt.xlabel("Life Expectancy")
plt.ylabel("GDP")

plt.show()

# %% [markdown]
# When you have a lot of different data points, you can choose scatter plot for your visualization.Scatter plot allows you to see relation between two variables.

# %% [markdown]
# **Task:** Build a scatter chart, with gdp_cap and life_exp.

# %%
plt.scatter(life_exp, gdp_cap)

plt.xlabel("Life Expectancy")
plt.ylabel("GDP")

plt.show()

# %% [markdown]
# Life expectancy increases as GDP increases above 10000

# %%
plt.scatter(gdp_cap, life_exp)


plt.show()

# %% [markdown]
# The whole point of visualization is understanding data and relationships between variables.

# %%
# Example of how to build a scatter plot

#import matplotlib
import matplotlib.pyplot as plt
#adding lists
x=[10,20,30,40,50,60,70,80,90]
y=[5,10,15,20,25,30,35,40,45]
#create scatterplot
plt.scatter(x,y)
plt.show()

# %% [markdown]
# **Using log Scale in Matplotlib**

# %%
# Using the Log Scale
#importing matplotlib
import matplotlib.pyplot as plt
#creating lists
x = [20, 200, 2000, 20000, 200000]
y = [30, 300, 3000, 30000, 300000]
#creating scatter plot
plt.scatter(x, y)
#applying log on x & y axis
plt.xscale('log')
plt.yscale('log')
plt.show()

# %% [markdown]
# Log scale isgood for looking at change in trend or growth

# %% [markdown]
# **Task** Change the scatter plot. A correlation
# will become clear when you display the GDP per capita on a logarithmic scale. Add the
# line plt.xscale('log').
# Finish off your script with plt.show()

# %%
plt.scatter(life_exp,gdp_cap)

plt.xlabel("Life Expectancy")
plt.ylabel("GDP")

plt.xscale('log')
plt.show()

# %% [markdown]
# **Histogram**

# %% [markdown]
# *   Histogram shows distribution of numerical data
# *   It shows frequency on vertical axis and another dimension on horizontal axis.
# *   It has bins where each bin has a minimum and maximum value
# *   To create ahistogram, use plt.hist(x).

# %%
# Creating Histogram Example

#importing matplotlib
import matplotlib.pyplot as plt
#creating lists
x = [10,15,20,25,40,45,70,90,100,125,125,150,150,175,20,15,40,40, 200]
#creating histogram
plt. hist(x)
plt.show()

# %% [markdown]
# You can define number of bins as required.
# In the previous task, you didn't specify the number of bins. By default, Python sets the number
# of bins to 10 in that case

# %%
# Creating Histrogram with bins
#importing matplotlib
import matplotlib.pyplot as plt

#creating lists
x = [10,15,20,25,40,45,70,90,100,125,125,150,150,175,20,15,40,40, 200]
#creating histogram

bin=15
plt. hist(x,bin)
plt.show()

# %% [markdown]
# **Task**: Build a histogram of life_exp, with 5 bins. Can you tell which bin contains the
# most observations?

# %%
plt.hist(life_exp,5)
plt.show()

# %% [markdown]
# Specifying bin boundaries

# %%
plt.hist(life_exp,bins=[10,20,30,40,50,60,70,80,90])
plt.show()

# %% [markdown]
# Most life expectancy falls between 70 to 80 age group.

# %%
# adding space between bins
plt.hist(life_exp,5, rwidth=0.7)
plt.show()

# %% [markdown]
# **Task** Build another histogram of life_exp, this time with 20 bin

# %%
plt.hist(life_exp,20)
plt.show()

# %% [markdown]
# Task: Build a histogram of life_exp with 5 Custom bins

# %%
plt.hist(life_exp, bins=[40, 50,60, 65,68,80])
plt.show()

# %% [markdown]
# **Add Labels on Plots**

# %%
#import matplotlib
import matplotlib.pyplot as plt
# Create data
x=[10,20,30,40,50,60,70,80,90]
y=[5,10,15,20,25,30,35,40,45]
# Plot
plt.scatter(x, y)
plt.title('Scatter plot ')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %% [markdown]
# **Task** Using the savings data create a scatter plot? And give a title of your plot
# also name x & y axis months & savings respectivly

# %%
# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
month=['Jen','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nev','Dec']
saving=[209.00,250.00,209.00,297.00,356.00,388.00,305.00,397.00,362.00,237.00,282.00,238.00]
#make line plot year on x-axis and pop on y-axis
plt.scatter(month,saving)
# Add title
plt.title('Monthly savings')
# Add axis labels
plt.xlabel('month')
plt.ylabel('saving')
#display the plot
plt.show()

# %% [markdown]
# **Ticks**

# %%
# Example
#Create scatter plot of using X & Y values
# importing matplotlib module
import matplotlib.pyplot as plt
# x-axis values
x = [5, 2, 9, 4, 7]
# Y-axis values
y = [10, 5, 8, 4, 2]
# Function to plot
plt.scatter(x, y)
plt.title('Scatter plot ')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Adapt the ticks on the x-axis & y-axis
plt.xticks([5, 2, 9, 4, 7], ["five","two","nine","four","seven"])
plt.yticks([10, 5, 8, 4, 2], ["ten","five","eight","four","two"])
plt.show()

# %% [markdown]
# **Task**

# %%
plt.scatter(gdp_cap,life_exp)

plt.xscale('log')

tick_val=[1000,10000,100000]
tick_lab=["1k", "10k", "100k"]

plt.title("Scatter Plot")
plt.xlabel("GDP Per Capita")
plt.ylabel("Life Expectancy")
plt.xticks(tick_val, tick_lab)
plt.show()

# %% [markdown]
# Solution

# %%
# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
# Strings
xlab = 'GDP per Capita [in USD]'
ylab = 'Life Expectancy [in years]'
title = 'World Development '
# Definition of tick_val and tick_lab
tick_val = [1000, 10000, 100000]
tick_lab = ['1k', '10k', '100k']
# Basic scatter plot, log scale
plt.scatter(gdp_cap, life_exp)
plt.xscale('log')
# Add axis labels
plt.xlabel(xlab)
plt.ylabel(ylab)
# Add title
plt.title(title)
# Adapt the ticks on the x-axis
plt.xticks(tick_val,tick_lab)
# After customizing, display the
plt.show()

# %% [markdown]
# **Sizes**

# %%
#import matplotlib
import matplotlib.pyplot as plt
#adding variables
x = [1,2,3,4,5,6,7,8]
y = [4,1,3,6,1,3,5,2]
size = [100,500,100,500,100,500,100,500]
#creating scatter plot
plt.scatter(x,y,s=size)
plt.title("Scatter plot with Sizes")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# **Task**

# %%
# Import numpy as np
import numpy as np
# Store pop as a numpy array: np_pop
population_Data=pd.read_csv('https://raw.githubusercontent.com/Masadn/PythonCourse/master/dataset/popdata1.csv')
pop=np.array(population_Data)
np_pop=(pop[:,0])

np_pop
# Out:
# array([3.60e+00, 3.33e+01, 1.24e+01, 4.03e+01, 2.04e+01, 8.20e+00,
#        7.09e-01, 1.50e+02, 1.04e+01, 8.08e+00, 9.12e+00, 4.55e+00,
#        1.64e+00, 1.90e+02, 7.32e+00, 1.43e+01, 8.39e+00, 1.41e+01,
#        1.77e+01, 3.34e+01, 4.37e+00, 1.02e+01, 1.63e+01, 1.32e+03,
#        4.42e+01, 7.11e-01, 6.46e+01, 3.80e+00, 4.13e+00, 1.80e+01,
#        4.49e+00, 1.14e+01, 1.02e+01, 5.47e+00, 4.96e-01, 9.32e+00,
#        1.38e+01, 8.03e+01, 6.94e+00, 5.51e-01, 4.91e+00, 7.65e+01,
#        5.24e+00, 6.11e+01, 1.45e+00, 1.69e+00, 8.24e+01, 2.29e+01,
#        1.07e+01, 1.26e+01, 9.95e+00, 1.47e+00, 8.50e+00, 7.48e+00,
#        6.98e+00, 9.96e+00, 3.02e-01, 1.11e+03, 2.24e+02, 6.95e+01,
#        2.75e+01, 4.11e+00, 6.43e+00, 5.81e+01, 2.78e+00, 1.27e+02,
#        6.05e+00, 3.56e+01, 2.33e+01, 4.90e+01, 2.51e+00, 3.92e+00,
#        2.01e+00, 3.19e+00, 6.04e+00, 1.92e+01, 1.33e+01, 2.48e+01,
#        1.20e+01, 3.27e+00, 1.25e+00, 1.09e+02, 2.87e+00, 6.85e-01,
# ...

# %%
population_Data.head()
# Out:
#    3.19E+01
# 0       3.6
# 1      33.3
# 2      12.4
# 3      40.3
# 4      20.4

# %%
population_Data.columns
# Out:
# Index(['3.19E+01'], dtype='object')

# %%
population_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   3.19E+01  142 non-null    float64
# dtypes: float64(1)
# memory usage: 1.2 KB

# %%
plt.scatter(gdp_cap, life_exp,s=np_pop)
plt.xscale("log")
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])


plt.show()

# %% [markdown]
# **Adding colorsto plot**

# %%
# Using Colors in a Scatter plot
#importing matplotlib
import matplotlib.pyplot as plt
#creating the x & y axis
x = [1,2,3,4,5,6,7,8]
y = [4,1,3,6,1,3,5,2]
size = [100,500,100,500,100,500,100,500]
plotcolor = ['red','orange','yellow','green','blue','yellow','green','blue']
#adding colors
plt.scatter(x,y,s=size,c=plotcolor)
#creating scatter plot
plt.title('Scatter plot with Colors')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# **Changing Opacity**

# %%
# Using opacity function in matplotlib
#import matplotlib
import matplotlib.pyplot as plt
#creating x & y values
x = [1,2,3,4,5,6,7,8]
y = [4,1,3,6,1,3,5,2]
size = [100,500,100,500,100,500,100,500]
plotcolor = ['red','orange','yellow','green','blue','yellow','green','blue']
#creating a scatter plot and decreasing opacity
plt.scatter(x,y,s=size,c=plotcolor ,alpha=0.4)
#adding titles & lables
plt.title('Scatter plot with Colors')
plt.xlabel('x')
plt.ylabel('y')
#show plot
plt.show()
